# %%
#1)multiply two arrays of same size elememt by element

import numpy as np

a=np.array([1,2,3])
b=np.array([3,4,5])
result=a*b
print("Element wise multiplication",result)
# Out:
# Element wise multiplication [ 3  8 15]

# %%
#2) calculator

def calculator():
    a = int(input("Enter a number: "))
    b = int(input("Enter a number: "))
    print("1.Addition")
    print("2.Substraction")
    print("3.Multiplication")
    print("4.Division")
    choice = int(input("Enter your choice: "))
    if(choice == 1):
        print(a+b)
    elif(choice == 2):
        print(a-b)
    elif(choice == 3):
        print(a*b)
    elif(choice == 4):
        print(a/b)
    else:
        print("Wrong choice")
        
calculator()
# Out:
# Enter a number: 5
# Enter a number: 10
# 1.Addition
# 2.Substraction
# 3.Multiplication
# 4.Division
# Enter your choice: 1
# 15

# %%
#3)Two Arrays are equal

def equal(a,b):
    if len(a) != len(b):
        return False
    for i in range(len(a)):
        if a[i] != b[i]:
            return False
        return True
a=[1,2,3,4]
b=[1,2,3,4]
if equal(a,b):
    print("Equal")
else:
    print("Not Equal")
# Out:
# Equal

# %%
#4)3x3 identity matrix
import numpy as np
identify_matrix = np.identity(3)
identify_matrix
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
#5) SVD

import numpy as np

A = np.array([[3, 1],
              [1, 3]])

print("Original matrix A:\n", A)

U, S, VT = np.linalg.svd(A)

print("\nMatrix U (Left singular vectors):\n", U)
print("\nSingular values (Sigma):\n", S)
print("\nMatrix V^T (Right singular vectors transpose):\n", VT)


Sigma = np.zeros((A.shape[0], A.shape[1]))  
np.fill_diagonal(Sigma, S)

print("\nDiagonal matrix Sigma:\n", Sigma)


A_reconstructed = U @ Sigma @ VT

print("\nReconstructed matrix A (U * Sigma * V^T):\n", np.round(A_reconstructed, 2))
# Out:
# Original matrix A:
#  [[3 1]
#  [1 3]]
#
# Matrix U (Left singular vectors):
#  [[-0.70710678 -0.70710678]
#  [-0.70710678  0.70710678]]
#
# Singular values (Sigma):
#  [4. 2.]
#
# Matrix V^T (Right singular vectors transpose):
#  [[-0.70710678 -0.70710678]
#  [-0.70710678  0.70710678]]
#
# Diagonal matrix Sigma:
#  [[4. 0.]
#  [0. 2.]]
#
# Reconstructed matrix A (U * Sigma * V^T):
#  [[3. 1.]
#  [1. 3.]]

# %%
#6)draw a line 
import matplotlib.pyplot as plt

x = [1, 2, 6, 18]
y = [3, 10, 12, 20]

plt.plot(x, y, color='black', marker='o', markerfacecolor='red', markeredgecolor='red')
plt.show()

# %%
#7) temp vs celsius

import matplotlib.pyplot as plt

temp = [12, 14, 16, 18, 20, 22, 24]
celcius = [100, 200, 250, 400, 300, 450, 500]

plt.plot(temp, celcius, marker='o')
plt.xlabel('Temperature')
plt.ylabel('Celsius')
plt.title('Temperature vs Celsius')

plt.show()

# %%
#8) lines in same plot

import matplotlib.pyplot as plt

x1 = [1, 2, 3, 4, 5]
y1 = [2, 4, 6, 8, 10]

x2 = [1, 2, 3, 4, 5]
y2 = [1, 3, 5, 7, 9]

plt.plot(x1, y1, label='Line 1', marker='o')
plt.plot(x2, y2, label='Line 2', marker='s')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple Lines on Same Plot')

plt.show()

# %%
#9) create multiple plots

import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]
y2 = [25, 16, 9, 4, 1]

plt.subplot(1, 2, 1)
plt.plot(x, y1, marker='o')
plt.title('Plot 1')

plt.subplot(1, 2, 2)
plt.plot(x, y2, marker='s')
plt.title('Plot 2')

plt.tight_layout()
plt.show()

# %%
#10) bar plot gender

import matplotlib.pyplot as plt
import numpy as np

labels = ['G1','G2','G3','G4','G5']
m = [22, 30, 35, 35, 26]
women = [25, 32, 30, 35, 29]

x = np.arange(len(labels))
print(x)
width = 0.35


plt.bar(x - width/2, men, width, label='Men')
plt.bar(x + width/2, women, width, label='Women')

plt.xlabel('Group')
plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(x, labels)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# [0 1 2 3 4]

# %%
import matplotlib.pyplot as plt

x = [1, 2, 6, 18]
y = [3, 10, 12, 20]


plt.plot(
    x, y,
    color='black',
    linestyle=':',              
    marker='o',
    markerfacecolor='red',
    markeredgecolor='red'
)

plt.title("Dotted Line Plot with Markers")
plt.show()
